# %%
import pandas as pd;
import numpy as np;

# %%
df=pd.read_csv("/content/fifa (1).csv")

# %%
df
# Out:
#       Unnamed: 0  sofifa_id  \
# 0              0     158023
# 1              1      20801
# 2              2       9014
# 3              3      41236
# 4              4     167495
# ...          ...        ...
# 9514        9514     208024
# 9515        9515     208510
# 9516        9516     209454
# 9517        9517     209992
# 9518        9518     210477
#
#                                              player_url         short_name  \
# 0     https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1     https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2     https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3     https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4     https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                 ...                ...
# 9514  https://sofifa.com/player/208024/murray-wallac...         M. Wallace
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4           4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  sofifa_id  \
# 9514        9514     208024
# 9515        9515     208510
# 9516        9516     209454
# 9517        9517     209992
# 9518        9518     210477
#
#                                              player_url      short_name  \
# 9514  https://sofifa.com/player/208024/murray-wallac...      M. Wallace
# 9515  https://sofifa.com/player/208510/pelayo-novo-g...          Pelayo
# 9516  https://sofifa.com/player/209454/mateusz-lewan...  M. Lewandowski
# 9517  https://sofifa.com/player/209992/andre-fomitsc...   A. Fomitschow
# 9518  https://sofifa.com/player/210477/patrick-mosch...       P. Möschl
#
#                 long_name  age         dob  height_cm  weight_kg nationality  \
# 9514       Murray Wallace   21  1993-01-10        188         73    Scotland
# 9515   Pelayo Novo García   23  1990-11-01        183         81       Spain
# 9516  Mateusz Lewandowski   21  1993-03-18        182         72      Poland
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2581 entries, 0 to 2580
# Data columns (total 81 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  2581 non-null   int64
#  1   sofifa_id                   2581 non-null   int64
#  2   player_url                  2581 non-null   object
#  3   short_name                  2581 non-null   object
#  4   long_name                   2581 non-null   object
#  5   age                         2581 non-null   int64
#  6   dob                         2581 non-null   object
#  7   height_cm                   2581 non-null   int64
#  8   weight_kg                   2581 non-null   int64
#  9   nationality                 2581 non-null   object
#  10  club_name                   2533 non-null   object
#  11  league_name                 2533 non-null   object
#  12  league_rank                 2532 non-null   float64
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4           4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5           5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 6           6         41  https://sofifa.com/player/41/andres-iniesta-lu...
# 7           7     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 8           8       7826  https://sofifa.com/player/7826/robin-van-persi...
# 9           9     121944  https://sofifa.com/player/121944/bastian-schwe...
#
#           short_name                            long_name  age         dob  \
# ...

# %%
df.tail(5)
# Out:
#       Unnamed: 0  sofifa_id  \
# 2576        2576     214327
# 2577        2577     214933
# 2578        2578     215215
# 2579        2579     217844
# 2580        2580     170074
#
#                                              player_url    short_name  \
# 2576  https://sofifa.com/player/214327/vladimir-hern...  V. Hernández
# 2577  https://sofifa.com/player/214933/diego-rodrigu...  D. Rodríguez
# 2578  https://sofifa.com/player/215215/fabricio-font...  F. Fontanini
# 2579  https://sofifa.com/player/217844/djavan-da-sil...        Djavan
# 2580  https://sofifa.com/player/170074/mark-davies/1...     M. Davies
#
#                              long_name  age         dob  height_cm  weight_kg  \
# 2576  Vladimir Javier Hernández Rivero   25  1989-02-08        160         61
# 2577            Diego Matías Rodríguez   25  1989-06-25        184         77
# 2578       Fabricio Bautista Fontanini   24  1990-03-30        180         80
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0      sofifa_id          age    height_cm    weight_kg  \
# count  2581.000000    2581.000000  2581.000000  2581.000000  2581.000000
# mean   1290.000000  167862.044169    26.770244   181.707090    76.505618
# std     745.214846   46820.665102     3.934973     6.847751     7.070990
# min       0.000000      27.000000    17.000000   160.000000    51.000000
# 25%     645.000000  158626.000000    24.000000   177.000000    72.000000
# 50%    1290.000000  182888.000000    27.000000   182.000000    76.000000
# 75%    1935.000000  197081.000000    29.000000   187.000000    81.000000
# max    2580.000000  225359.000000    43.000000   203.000000   110.000000
#
#        league_rank      overall    potential     value_eur       wage_eur  \
# count  2532.000000  2580.000000  2580.000000  2.580000e+03    2580.000000
# mean      1.058847    75.022093    77.592636  4.632552e+06   52488.759690
# std       0.235384     3.419928     3.969976  5.820179e+06   37949.593484
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['goalkeeping_positioning'].max()
# Out:
# 90.0

# %%
df['attacking_heading_accuracy'].min()
# Out:
# 21.0

# %%
df[df.goalkeeping_positioning>20]
# Out:
#       Unnamed: 0  sofifa_id  \
# 4              4     167495
# 5              5     176580
# 21            21     192119
# 39            39     167948
# 43            43      48940
# ...          ...        ...
# 2517        2517     193312
# 2549        2549     178086
# 2568        2568     199764
# 2573        2573     204120
# 2577        2577     214933
#
#                                              player_url    short_name  \
# 4     https://sofifa.com/player/167495/manuel-neuer/...      M. Neuer
# 5     https://sofifa.com/player/176580/luis-suarez/1...     L. Suárez
# 21    https://sofifa.com/player/192119/thibaut-court...   T. Courtois
# 39    https://sofifa.com/player/167948/hugo-lloris/1...     H. Lloris
# 43     https://sofifa.com/player/48940/petr-cech/150002       P. Čech
# ...                                                 ...           ...
# 2517  https://sofifa.com/player/193312/sebastian-mie...    S. Mielitz
# ...

# %%
df[df.goalkeeping_positioning <20]
# Out:
#       Unnamed: 0  sofifa_id  \
# 0              0     158023
# 1              1      20801
# 2              2       9014
# 3              3      41236
# 6              6         41
# ...          ...        ...
# 2574        2574     205343
# 2575        2575     211249
# 2576        2576     214327
# 2578        2578     215215
# 2579        2579     217844
#
#                                              player_url         short_name  \
# 0     https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1     https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2     https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3     https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 6     https://sofifa.com/player/41/andres-iniesta-lu...            Iniesta
# ...                                                 ...                ...
# 2574  https://sofifa.com/player/205343/jean-daniel-a...      J. Akpa Akpro
# ...

# %%
df['goalkeeping_positioning'].mean()
# Out:
# 16.18294573643411

# %%
df.goalkeeping_positioning
# Out:
# 0       14.0
# 1       14.0
# 2        5.0
# 3        9.0
# 4       90.0
#         ...
# 2576    12.0
# 2577    70.0
# 2578     8.0
# 2579     6.0
# 2580     NaN
# Name: goalkeeping_positioning, Length: 2581, dtype: float64

# %%
df.isna().sum()
# Out:
# Unnamed: 0                 0
# sofifa_id                  0
# player_url                 0
# short_name                 0
# long_name                  0
#                           ..
# goalkeeping_diving         1
# goalkeeping_handling       1
# goalkeeping_kicking        1
# goalkeeping_positioning    1
# goalkeeping_reflexes       1
# Length: 81, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# sofifa_id                  0
# player_url                 0
# short_name                 0
# long_name                  0
#                           ..
# goalkeeping_diving         1
# goalkeeping_handling       1
# goalkeeping_kicking        1
# goalkeeping_positioning    1
# goalkeeping_reflexes       1
# Length: 81, dtype: int64

# %%
df.dropna(axis = 1, inplace = False)
# Out:
#       Unnamed: 0  sofifa_id  \
# 0              0     158023
# 1              1      20801
# 2              2       9014
# 3              3      41236
# 4              4     167495
# ...          ...        ...
# 2576        2576     214327
# 2577        2577     214933
# 2578        2578     215215
# 2579        2579     217844
# 2580        2580     170074
#
#                                              player_url         short_name  \
# 0     https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1     https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2     https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3     https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4     https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                 ...                ...
# 2576  https://sofifa.com/player/214327/vladimir-hern...       V. Hernández
# ...

# %%
df.dropna(axis = 0, inplace = True)

# %%
df.dropna(axis = 1, inplace = False)
# Out:
#       Unnamed: 0  sofifa_id  \
# 0              0     158023
# 1              1      20801
# 2              2       9014
# 3              3      41236
# 4              4     167495
# ...          ...        ...
# 2576        2576     214327
# 2577        2577     214933
# 2578        2578     215215
# 2579        2579     217844
# 2580        2580     170074
#
#                                              player_url         short_name  \
# 0     https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1     https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2     https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3     https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4     https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                 ...                ...
# 2576  https://sofifa.com/player/214327/vladimir-hern...       V. Hernández
# ...

# %%
df.dropna(axis = 0, inplace = False)
# Out:
#       Unnamed: 0  sofifa_id  \
# 0              0     158023
# 1              1      20801
# 2              2       9014
# 3              3      41236
# 4              4     167495
# ...          ...        ...
# 2576        2576     214327
# 2577        2577     214933
# 2578        2578     215215
# 2579        2579     217844
# 2580        2580     170074
#
#                                              player_url         short_name  \
# 0     https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1     https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2     https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3     https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4     https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                 ...                ...
# 2576  https://sofifa.com/player/214327/vladimir-hern...       V. Hernández
# ...

# %%
df
# Out:
#       Unnamed: 0  sofifa_id  \
# 0              0     158023
# 1              1      20801
# 2              2       9014
# 3              3      41236
# 4              4     167495
# ...          ...        ...
# 2576        2576     214327
# 2577        2577     214933
# 2578        2578     215215
# 2579        2579     217844
# 2580        2580     170074
#
#                                              player_url         short_name  \
# 0     https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1     https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2     https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3     https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4     https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                 ...                ...
# 2576  https://sofifa.com/player/214327/vladimir-hern...       V. Hernández
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'sofifa_id', 'player_url', 'short_name', 'long_name',
#        'age', 'dob', 'height_cm', 'weight_kg', 'nationality'],
#       dtype='object')

# %%
df=df.drop(columns=['short_name',])

# %%
df
# Out:
#       Unnamed: 0  sofifa_id  \
# 0              0     158023
# 1              1      20801
# 2              2       9014
# 3              3      41236
# 4              4     167495
# ...          ...        ...
# 2576        2576     214327
# 2577        2577     214933
# 2578        2578     215215
# 2579        2579     217844
# 2580        2580     170074
#
#                                              player_url  \
# 0     https://sofifa.com/player/158023/lionel-messi/...
# 1     https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     https://sofifa.com/player/9014/arjen-robben/15...
# 3     https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     https://sofifa.com/player/167495/manuel-neuer/...
# ...                                                 ...
# 2576  https://sofifa.com/player/214327/vladimir-hern...
# 2577  https://sofifa.com/player/214933/diego-rodrigu...
# 2578  https://sofifa.com/player/215215/fabricio-font...
# ...

# %%
len(df)
# Out:
# 2581

# %%
df.age.dtypes
# Out:
# dtype('int64')

# %%
df.age.unique()
# Out:
# array([27, 29, 30, 32, 28, 23, 31, 24, 25, 22, 26, 34, 33, 35, 21, 36, 20,
#        19, 37, 43, 41, 18, 38, 17, 39])

# %%
df.age.nunique()
# Out:
# 25

# %%
df1=pd.DataFrame({'city':['A','B','C'],'day1':[22,56,89],'day2':[34,28,45],'day3':[27,89,43],'day4':[12,67,90],'day5':[3,56,37]})

# %%
df1
# Out:
#   city  day1  day2  day3  day4  day5
# 0    A    22    34    27    12     3
# 1    B    56    28    89    67    56
# 2    C    89    45    43    90    37

# %%
df1.head()
# Out:
#   city  day1  day2  day3  day4  day5
# 0    A    22    34    27    12     3
# 1    B    56    28    89    67    56
# 2    C    89    45    43    90    37

# %%
df1.tail()
# Out:
#   city  day1  day2  day3  day4  day5
# 0    A    22    34    27    12     3
# 1    B    56    28    89    67    56
# 2    C    89    45    43    90    37

# %%
df1.city.max()
# Out:
# 'C'

# %%
df1.day1.max()
# Out:
# 89

# %%
df1.day5.min()
# Out:
# 3

# %%
df1.max()
# Out:
# city     C
# day1    89
# day2    45
# day3    89
# day4    90
# day5    56
# dtype: object

# %%
df1.min()
# Out:
# city     A
# day1    22
# day2    28
# day3    27
# day4    12
# day5     3
# dtype: object

# %%
df2=pd.DataFrame({'Movie_name':['SSH','RRR','H20','MAA','MOM','KKR','RCB','BNG','BRO','GOA'],'Relase_time':['W','N','FS','W','N','LW','W','N','LW','W'],'Genre':['COMDEY','HORROR','ACTION','THILLER','ROMANCE','COMDEY','ACTION','HORROR','ACTION','ROMANCE'],'BOX_OFFICE_COLLECTION':[20000,40000,1000,5000,60000,3000,70000,200000,50000,900000],'YOUTUDE_VIEWS':[2000,6000,50000,70000,80000,23000,50000,1000,5678,9876]})

# %%
df2
# Out:
#   Movie_name Relase_time    Genre  BOX_OFFICE_COLLECTION  YOUTUDE_VIEWS
# 0        SSH           W   COMDEY                  20000           2000
# 1        RRR           N   HORROR                  40000           6000
# 2        H20          FS   ACTION                   1000          50000
# 3        MAA           W  THILLER                   5000          70000
# 4        MOM           N  ROMANCE                  60000          80000
# 5        KKR          LW   COMDEY                   3000          23000
# 6        RCB           W   ACTION                  70000          50000
# 7        BNG           N   HORROR                 200000           1000
# 8        BRO          LW   ACTION                  50000           5678
# 9        GOA           W  ROMANCE                 900000           9876

# %%
df2.tail()
# Out:
#   Movie_name Relase_time    Genre  BOX_OFFICE_COLLECTION  YOUTUDE_VIEWS
# 5        KKR          LW   COMDEY                   3000          23000
# 6        RCB           W   ACTION                  70000          50000
# 7        BNG           N   HORROR                 200000           1000
# 8        BRO          LW   ACTION                  50000           5678
# 9        GOA           W  ROMANCE                 900000           9876

# %%
df2.head()
# Out:
#   Movie_name Relase_time    Genre  BOX_OFFICE_COLLECTION  YOUTUDE_VIEWS
# 0        SSH           W   COMDEY                  20000           2000
# 1        RRR           N   HORROR                  40000           6000
# 2        H20          FS   ACTION                   1000          50000
# 3        MAA           W  THILLER                   5000          70000
# 4        MOM           N  ROMANCE                  60000          80000
#   Movie_name Relase_time    Genre  BOX_OFFICE_COLLECTION  YOUTUDE_VIEWS
# 0        SSH           W   COMDEY                  20000           2000
# 1        RRR           N   HORROR                  40000           6000
# 2        H20          FS   ACTION                   1000          50000
# 3        MAA           W  THILLER                   5000          70000
# 4        MOM           N  ROMANCE                  60000          80000

# %%
df2.BOX_OFFICE_COLLECTION.max()
# Out:
# 900000

# %%
df2.BOX_OFFICE_COLLECTION.min()
# Out:
# 1000

# %%
len(df2)
# Out:
# 10

# %%
 df2.columns = [i.upper() for i in df2]
 print(df2.columns)
# Out:
# Index(['MOVIE_NAME', 'RELASE_TIME', 'GENRE', 'BOX_OFFICE_COLLECTION',
#        'YOUTUDE_VIEWS'],
#       dtype='object')

# %%
df2
# Out:
#   MOVIE_NAME RELASE_TIME    GENRE  BOX_OFFICE_COLLECTION  YOUTUDE_VIEWS
# 0        SSH           W   COMDEY                  20000           2000
# 1        RRR           N   HORROR                  40000           6000
# 2        H20          FS   ACTION                   1000          50000
# 3        MAA           W  THILLER                   5000          70000
# 4        MOM           N  ROMANCE                  60000          80000
# 5        KKR          LW   COMDEY                   3000          23000
# 6        RCB           W   ACTION                  70000          50000
# 7        BNG           N   HORROR                 200000           1000
# 8        BRO          LW   ACTION                  50000           5678
# 9        GOA           W  ROMANCE                 900000           9876

# %%
df2.BOX_OFFICE_COLLECTION.mean()
# Out:
# 134900.0

# %%
df2.YOUTUDE_VIEWS.mean()
# Out:
# 29755.4

# %%
df2.YOUTUDE_VIEWS.max()
# Out:
# 80000

# %%
df2.YOUTUDE_VIEWS.min()
# Out:
# 1000
